# %% [markdown]
# Explore different Keras optimitzers on the MNIST dataset.
# -----
#
# ![](http://myselph.de/mnistExamples.png)
#
# [Based on this code](https://github.com/fchollet/keras/blob/master/examples/mnist_cnn.py)

# %% [markdown]
# Check out this demo first: http://kurg.org/mnist/index.html?id=5

# %% [markdown]
# -----
# Setup

# %%
reset -fs

# %%
import keras
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ----
# Prepare data
# ----

# %%
from keras.datasets import mnist

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
from matplotlib import pyplot
from scipy.misc import toimage

# %matplotlib inline

# %%
# Create a grid of 3x3 images
for i in range(0, 9):
    pyplot.subplot(330 + 1 + i)
    pyplot.imshow(toimage(x_train[i]))
    
pyplot.show()

# %%
from keras import backend as K

# %%
# Input image dimensions
img_rows, img_cols = 28, 28

if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 1, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %%
# Convert class vectors to binary class matrices
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %% [markdown]
# ----
# Define architecture
# -----

# %%
from keras.models import Sequential
from keras.layers import None # TODO: Add imports

# %%
# TODO: Create a CNN architecture
model = Sequential()

model.add(None) # TODO: Add 2d 2D convolution layer
model.add(None) # TODO: Add 2d 2D convolution layer
model.add(None) # TODO: Add max pooling layer
model.add(None) # TODO: Add dropout layer
model.add(None) # TODO: Add flatten layer
model.add(None) # TODO: Add dense layer
model.add(None) # TODO: Add output layer

# %% [markdown]
# ----
# Optimitzers
# -----

# %%
from keras.optimizers import <tab>  # TODO: Look at the options. Add "out-of-the-box" optimizer
# Out:
#   File "<ipython-input-15-5985c1761509>", line 1
#     from keras.optimizers import <tab>  # TODO: look at the options
#                                  ^
# SyntaxError: invalid syntax

# %% [markdown]
# Read about them https://keras.io/optimizers/

# %% [markdown]
# TODO: How many "out-of-the-box" optimizer options does Keras have?

# %% [markdown]
# ----
# Train model
# -----

# %%
batch_size = 128
epochs = 1 # Leave very small (2-3) for the sake of training speed

model.compile(optimizer=optimizer, 
              loss=keras.losses.categorical_crossentropy,
              metrics=['accuracy'])

model.fit(x_train, 
        y_train,
        batch_size=batch_size, 
        epochs=epochs,
        verbose=True, 
        validation_split=.1)

score = model.evaluate(x_test, 
                       y_test, 
                       verbose=False)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
#  - ETA: 36s - loss: 1.0860 - acc: 0.7257
# Test loss: 0.270081200379
# Test accuracy: 0.9237

# %%
# TODO: Perform 1-d grid search to find the best Keras optimitzer for this model

# %% [markdown]
# <details><summary>
# Click here for a hint…
# </summary>
# Create a list of all optimizers. Then iterate through all of them and finding each one's test accuracy. The one with the highest test accuracy is the winner!
# </details>

# %% [markdown]
# -----
# TODO: Answer the following questions:
# ----

# %% [markdown]
# Which optimitzer is the best optimitzer? Does that surprise you? Why do you think that is?

# %% [markdown]
# What is the intution behind that optimitzer?

# %% [markdown]
# ----
# Challenge Activities
# ----

# %% [markdown]
# Tune the hyperparameters of the best optimitzer

# %% [markdown]
# Which hyperparameter is most important for an optimitizer?

# %% [markdown]
# <br>
# <br>
# <br>
#
# ----
